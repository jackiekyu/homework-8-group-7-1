# %%
from cibin import *
import numpy as np
import pandas as pd
import math
from itertools import combinations
from itertools import filterfalse

# %%
nchoosem(5, 3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-5c6817474bf0> in <module>
# ----> 1 nchoosem(5, 3)
#
# NameError: name 'nchoosem' is not defined

# %%
tau_twoside_ci(1, 1, 1, 13, .05, 10**5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-d997b029bb07> in <module>
# ----> 1 tau_twoside_ci(1, 1, 1, 13, .05, 10**5)
#
# NameError: name 'tau_twoside_ci' is not defined

# %%
# %%bash
# pycodestyle cibin.py
# Out:
# cibin.py:1:1: E902 FileNotFoundError: [Errno 2] No such file or directory: 'cibin.py'
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-10-c47874f3de74> in <module>
# ----> 1 get_ipython().run_cell_magic('bash', '', 'pycodestyle cibin.py\n')
#
# /opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2397             with self.builtin_trap:
#    2398                 args = (magic_arg_s, cell)
# -> 2399                 result = fn(*args, **kwargs)
#    2400             return result
#    2401
#
# /opt/conda/lib/python3.8/site-packages/IPython/core/magics/script.py in named_script_magic(line, cell)
#     140             else:
#     141                 line = script
# --> 142             return self.shebang(line, cell)
#     143
#     144         # write a basic docstring:
#
# ...

# %%
# %%bash
# pep257 cibin.py
# Out:
# [Errno 2] No such file or directory: 'cibin.py'
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-11-f8d5de463136> in <module>
# ----> 1 get_ipython().run_cell_magic('bash', '', 'pep257 cibin.py\n')
#
# /opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2397             with self.builtin_trap:
#    2398                 args = (magic_arg_s, cell)
# -> 2399                 result = fn(*args, **kwargs)
#    2400             return result
#    2401
#
# /opt/conda/lib/python3.8/site-packages/IPython/core/magics/script.py in named_script_magic(line, cell)
#     140             else:
#     141                 line = script
# --> 142             return self.shebang(line, cell)
#     143
#     144         # write a basic docstring:
#
# <decorator-gen-103> in shebang(self, line, cell)
#
# ...

# %%
# %%bash
# pytest cibin.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.8, pytest-6.2.3, py-1.10.0, pluggy-0.13.1
# rootdir: /home/jovyan/stat159-site/Hw/homework-8-group-7-1
# plugins: cov-2.11.1, anyio-2.2.0
# collected 0 items
#
# ============================ no tests ran in 0.03s =============================
# ERROR: file or directory not found: cibin.py
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-12-332d2afbc920> in <module>
# ----> 1 get_ipython().run_cell_magic('bash', '', 'pytest cibin.py\n')
#
# /opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2397             with self.builtin_trap:
#    2398                 args = (magic_arg_s, cell)
# -> 2399                 result = fn(*args, **kwargs)
#    2400             return result
# ...
